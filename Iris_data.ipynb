# %% [markdown]
# # Assignment - Iris Dataset 🌷

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# It Will ignore some unneccessery warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Data
df=pd.read_csv("iris.csv")

# %%
# Exploring the data
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Quick statistical Analysis of the Dataset
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# <b> We can see that the mean and median values don't have a large difference among their values so no data transformation is required.

# %%
# Checking for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Step - 2:  EDA

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### SepalLengthCm

# %%
plt.subplot(1,2,1)

plt.rcParams['figure.figsize'] = (10, 2)
sns.set_style("darkgrid")
sns.boxplot(df['SepalLengthCm'])
plt.title('Boxplot of SepalLengthCm')

plt.subplot(1,2,2)
plt.rcParams['figure.figsize'] = (16, 6)
sns.distplot(df['SepalLengthCm'], color = 'blue')
plt.axvline(df['SepalLengthCm'].mean(),color='black', label='Mean')
plt.title('Distribution of SepalLengthCm')
plt.show()

# %% [markdown]
# <b> From the distribution we can observe that the distribution of Sepal length appears to be normal distribution.
#
#  We can also observe that the median and mean values are nearly equal i.e. 5.8
#
#  The Highest frequency of sepal length is between 6.0 and 6.5 which is around 45.

# %% [markdown]
# ## SepalWidthCm

# %%
plt.subplot(1,2,1)

plt.rcParams['figure.figsize'] = (16, 6)
sns.set_style("darkgrid")
sns.boxplot(df['SepalWidthCm'])
plt.title('Boxplot of SepalWidthCm')

plt.subplot(1,2,2)
plt.rcParams['figure.figsize'] = (16, 6)
sns.distplot(df['SepalWidthCm'], color = 'blue')
plt.axvline(df['SepalWidthCm'].mean(),color='black', label='Mean')
plt.title('Distribution of SepalWidthCm')
plt.show()

# %% [markdown]
# <b> For Sepal width the distribution appears to be normal.From boxplot we can observe that there are few outliers in the data.
#
#  We can observe high frequency at 3.0 cm .The meadian and mean values are equal to 3.0

# %% [markdown]
# ## PetalLengthCm

# %%
plt.subplot(1,2,1)

plt.rcParams['figure.figsize'] = (10, 4)
sns.set_style("darkgrid")
sns.boxplot(df['PetalLengthCm'])
plt.title('Boxplot of PetalLengthCm')

plt.subplot(1,2,2)
plt.rcParams['figure.figsize'] = (16, 6)
sns.distplot(df['PetalLengthCm'], color = 'blue')
plt.axvline(df['PetalLengthCm'].mean(),color='black', label='Mean')
plt.title('Distribution of PetalLengthCm')
plt.show()

# %% [markdown]
# <b> The Petal length distribution is not symmetrics as it has two peaks.
#     The mean is less than median.
#     The Highest frequency of petal width is between 1.0 to 2.0 which is around 30.

# %% [markdown]
# ## PetalWidthCm

# %%
plt.subplot(1,2,1)

plt.rcParams['figure.figsize'] = (16, 6)
sns.set_style("darkgrid")
sns.boxplot(df['PetalWidthCm'])
plt.title('Boxplot of PetalWidthCm')

plt.subplot(1,2,2)
plt.rcParams['figure.figsize'] = (16, 6)
sns.distplot(df['PetalWidthCm'], color = 'blue')
plt.axvline(df['PetalWidthCm'].mean(),color='black', label='Mean')
plt.title('Distribution of PetalWidthCm')
plt.show()

# %% [markdown]
# <b>The distribution appears to be bimodal.
#     The mean is less than median.
#     The Highest frequency of petal width is between 0 to 0.5 which is around 67.

# %% [markdown]
# ## Species

# %%
plt.figure(figsize=(6,4))
sns.countplot(df['Species'])
plt.show()

# %% [markdown]
# <b> Each kind of species has equal count i.e.50

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lmplot( x="SepalLengthCm", y="SepalWidthCm", data=df, fit_reg=True, hue='Species', legend=True)

# %% [markdown]
# <b> Iris Setosa species has smaller sepal length but higher width.
# Versicolor lies in almost middle for length as well as width
# Virginica has larger sepal lengths and smaller sepal widths

# %%
sns.lmplot( x="PetalLengthCm", y="PetalWidthCm", data=df, fit_reg=True, hue='Species', legend=True)

# %% [markdown]
# <b> Setosa species have the smallest petal length as well as petal width
# Versicolor species have average petal length and petal width
# Virginica species have the highest petal length as well as petal width

# %%
sns.pairplot(df,hue='Species')

# %% [markdown]
# <b> High co relation between petal length and width columns.
# Setosa has both low petal length and width
# Versicolor has both average petal length and width
# Virginica has both high petal length and width.
# Sepal width for setosa is high and length is low.
# Versicolor have average values for for sepal dimensions.
# Virginica has small width but large sepal length

# %%
plt.figure(figsize=(16, 6))

plt.subplot(121)
sns.swarmplot(data = df, x='Species', y='SepalLengthCm')
plt.title('SepalLength')

plt.subplot(122)
sns.swarmplot(data = df, x='Species', y='SepalWidthCm')
plt.title('SepalWidth')

plt.show()

# %% [markdown]
# <b> The sepal length of Iris-setosa is concentrated at 5.0  For versicolor it is between 5.5 to6.5.virginica having more values around 6.3

# %% [markdown]
# <b> The sepal width of setosa flowers is mostly distributed at 3.4 where as versicolor and virginica are having more values concentrated at 3.0

# %%
plt.figure(figsize=(16, 6))

plt.subplot(121)
sns.swarmplot(data = df, x='Species', y='PetalLengthCm')
plt.title('PetalLenth')

plt.subplot(122)
sns.swarmplot(data = df, x='Species', y='PetalWidthCm')
plt.title('PetalWidth')

plt.show()

# %% [markdown]
# <b> The petal length of setosa flowers is highly distributed around 1.5 and for versicolor it is around 4.5 We can observe more values of virginica at 5.1

# %% [markdown]
# <b>The petal width of setosa flowers is highly distributed at 0.2 and for versi color it is around 1.3 We can observe at 1.8 most values of virginica are distributed.

# %%
# Heatmap
fig = plt.figure(figsize = (10,5))
sns.heatmap(df.corr(), cmap='Blues', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b> From the above heatmap, we see that petal length and petal width have a high correlation, petal width and sepal length have good correlation as well as petal length and sepal length have good correlations.

# %% [markdown]
# ## Step - 3:

# %% [markdown]
# ### a. Identifying the input and output :

# %%
inputs=df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
inputs.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
target=df[['Species']]
target.head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
#  ### b. Identifying the ML Task :
#  <b> Given SepalLength, PetalLength, SepalWidth and PetalWidth,we have to predict the Species of the Iris Flower.
#
#  <b> Target variable is given - Supervised.
#
#  <b> Target variable is Discrete - Classification Task.

# %% [markdown]
# ### c. Identifying the Evaluation Metric :

# %% [markdown]
# <b> Since the task is classification we use Accuracy Score as evaluation metric.

# %% [markdown]
# ## Step - 4: Splitting the dataset into Training and Testing :

# %%
# split into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(inputs, target, train_size=0.75, random_state=100)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (112, 4) (112, 1)
# (38, 4) (38, 1)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Step - 5: Data preparation on train data:
# ### Numerical Variables - Standardization

# %%
# scaling the numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = pd.DataFrame(scaler.fit_transform(X_train), 
                      columns = X_train.columns)

X_train.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.605209      0.837094       1.060662      1.587319
# 1      -0.007661     -0.601594       0.771343      1.587319
# 2      -1.601121     -1.800502      -1.427476     -1.205032
# 3      -0.375383     -1.081157       0.366298     -0.008311
# 4       1.585800     -0.122032       1.234253      1.188411

# %% [markdown]
# ### Categorical - LabelEncoding

# %%
species_encoder = {'Iris-setosa' : 1, 'Iris-versicolor' : 2, 'Iris-virginica' : 3 }

y_train['Species'] = y_train['Species'].apply(lambda x : species_encoder[x])

y_train.head()
# Out:
#      Species
# 136        3
# 114        3
# 41         1
# 90         2
# 102        3

# %% [markdown]
# ## Step - 6: Data preparation on test data:

# %% [markdown]
# ### Numerical Variables - Standardization

# %%
X_test = pd.DataFrame(scaler.transform(X_test), 
                      columns = X_test.columns)
X_test.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.727782     -0.601594       1.060662      1.188411
# 1      -1.233400      0.837094      -1.253885     -1.338001
# 2       2.321243     -1.081157       1.812889      1.454349
# 3      -0.130235      3.234908      -1.311749     -1.072063
# 4       0.605209     -0.841376       0.655616      0.789504

# %% [markdown]
# ### Categorical - LabelEncoding

# %%
species_encoder = {'Iris-setosa' : 1, 'Iris-versicolor' : 2, 'Iris-virginica' : 3 }

y_test['Species'] = y_test['Species'].apply(lambda x : species_encoder[x])

y_test.head()
# Out:
#      Species
# 128        3
# 11         1
# 118        3
# 15         1
# 123        3

# %% [markdown]
# ## Step - 7: Model Training Phase

# %% [markdown]
# ##  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
KNN_accuracy=accuracy_score(y_test, y_test_pred)
KNN_accuracy
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
Logistic_accuracy=accuracy_score(y_test, y_test_pred)
Logistic_accuracy
# Out:
# 0.9473684210526315

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
SVM_accuracy=accuracy_score(y_test, y_test_pred)
SVM_accuracy
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
DT_accuracy=accuracy_score(y_test, y_test_pred)
DT_accuracy
# Out:
# 0.9473684210526315

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred_ = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
RandomForest_accuracy=accuracy_score(y_test, y_test_pred_)
RandomForest_accuracy
# Out:
# 0.9473684210526315

# %% [markdown]
# ## Step - 8: Displaying a plot which shows all the algorithms applied along with the accuracies achieved.

# %%
Algorithms=['KNN','Logistic Regression','Support Vector Machines','Decision Trees','Random Forest']
Accuracy=[0.9473684210526315,0.9473684210526315,0.9736842105263158,0.9473684210526315,0.9473684210526315]
df_accuracy = pd.DataFrame(list(zip(Algorithms, Accuracy)),columns =['Classifier', 'Accuracy'])
df_accuracy
# Out:
#                 Classifier  Accuracy
# 0                      KNN  0.947368
# 1      Logistic Regression  0.947368
# 2  Support Vector Machines  0.973684
# 3           Decision Trees  0.947368
# 4            Random Forest  0.947368

# %%
plt.figure(figsize=(10, 4))
sns.barplot(x='Classifier', y='Accuracy', data=df_accuracy)

plt.xlabel('Algorithms applied')
plt.title('Classifier Accuracy')
plt.show()

# %% [markdown]
# <b> From the accuracy scores Support Vector Machines algorithm is having the highest accuracy.
